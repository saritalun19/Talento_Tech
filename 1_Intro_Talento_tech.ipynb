# %% [markdown]
# <a href="https://colab.research.google.com/github/saritalun19/Talento_Tech/blob/main/1_Intro_Talento_tech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ingreso de nuevos datos

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path='/content/ventas.xlsx'

# %%
import pandas as pd

# %% [markdown]
# # Creación y lectura de Dataframes:
#
#
#
# *   pd.df(data): Creada un dataframe a partir de datos
# *   pd.read_Csv('file.csv'): Lee un archivo CSV y crea un dataframe
# *  pd.read_Excel('file.xlsx'): LEe un archivo excel y crea un dataframe

# %%
df_ventas=pd.read_excel(path)
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %% [markdown]
# # Visualización y explotación de datos:
#
# * df.head(): muestra las primeras filas del datarame
# * df.tail(): muestra las ultimas filas del dataframe
# * df.info(): Muestra información del datafrmae (Tipos de datos, valores no nulos)
# * df.describe(): Proporciona estadisticas para columnas numericas

# %%
#Muestra la lista con nombres de las cilumnas del df
df_ventas.columns
# Out:
# Index(['Fecha', 'Region', 'Producto', 'Vendedor', 'Ventas', 'Unnamed: 5'], dtype='object')

# %%
#Muestra las primeras filas del df
df_ventas.head()
# Out:
#                  Fecha   Region    Producto Vendedor  Ventas Unnamed: 5
# 0  2024-01-31 00:00:00  Central  Accesorios    David  8287.0        NaN
# 1  2024-02-01 00:00:00  Central  Accesorios    Karen  6909.0        NaN
# 2  2024-02-06 00:00:00     Este  Accesorios      Ana  9323.0        NaN
# 3  2024-02-07 00:00:00     Este  Accesorios    Lucas  7667.0        NaN
# 4  2024-02-12 00:00:00    Oeste  Accesorios    Kevin  4744.0        NaN

# %%
#Ultimas filas del dataframe
df_ventas.tail()
# Out:
#                                                 Fecha Region Producto  \
# 25              ¿Cuál es la venta más alta realizada?    NaN      NaN
# 26      ¿Cuál es la región con mas ventas realizadas?    NaN      NaN
# 27      ¿Cuál fue el día que más se vendio en el mes?    NaN      NaN
# 28  ¿Del día mas vendido en el mes, quien fue el v...    NaN      NaN
# 29     ¿Cuál fue el producto menos vendido en el mes?    NaN      NaN
#
#    Vendedor  Ventas              Unnamed: 5
# 25      NaN     NaN                   32855
# 26      NaN     NaN                 Central
# 27      NaN     NaN     2024-02-16 00:00:00
# 28      NaN     NaN                   Kevin
# 29      NaN     NaN  Se vendieron por igual

# %%
df_ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Fecha       28 non-null     object
#  1   Region      18 non-null     object
#  2   Producto    18 non-null     object
#  3   Vendedor    18 non-null     object
#  4   Ventas      19 non-null     float64
#  5   Unnamed: 5  10 non-null     object
# dtypes: float64(1), object(5)
# memory usage: 1.5+ KB

# %%
df_ventas.describe()
# Out:
#               Ventas
# count      19.000000
# mean    25214.000000
# std     52501.045578
# min      4744.000000
# 25%      8533.500000
# 50%     10711.000000
# 75%     16814.500000
# max    239533.000000

# %% [markdown]
# # Ejercicios de la clase:

# %%
#1. Mostrar las primeras filas del dataframe
df_ventas.head(5)
# Out:
#                  Fecha   Region    Producto Vendedor  Ventas Unnamed: 5
# 0  2024-01-31 00:00:00  Central  Accesorios    David  8287.0        NaN
# 1  2024-02-01 00:00:00  Central  Accesorios    Karen  6909.0        NaN
# 2  2024-02-06 00:00:00     Este  Accesorios      Ana  9323.0        NaN
# 3  2024-02-07 00:00:00     Este  Accesorios    Lucas  7667.0        NaN
# 4  2024-02-12 00:00:00    Oeste  Accesorios    Kevin  4744.0        NaN

# %%
#2. CAlcular el total de ventas por region
ventas_region=df_ventas.groupby('Region')['Ventas'].sum()
ventas_region
# Out:
# Region
# Central    90295.0
# Este       63555.0
# Oeste      85683.0
# Name: Ventas, dtype: float64

# %%
#3. Filtrar el dataframe para mostrar solo ventas realizadas por David
ventas_david=df_ventas[df_ventas['Vendedor']== 'David']
ventas_david
# Out:
#                   Fecha   Region      Producto Vendedor   Ventas Unnamed: 5
# 0   2024-01-31 00:00:00  Central    Accesorios    David   8287.0        NaN
# 6   2024-02-02 00:00:00  Central  Dispositivos    David  11420.0        NaN
# 12  2024-02-04 00:00:00  Central      Sistemas    David  20098.0        NaN

# %%
#5. Calcular el promedio de ventas por region con decimales
ventas_prom_region=df_ventas.groupby('Region')['Ventas'].mean()
ventas_prom_region
# Out:
# Region
# Central    15049.166667
# Este       10592.500000
# Oeste      14280.500000
# Name: Ventas, dtype: float64

# %%
#5. Calcular el promedio de ventas por region con decimales
ventas_region=df_ventas.groupby('Region')['Ventas'].mean().round(2)
ventas_region
# Out:
# Region
# Central    15049.17
# Este       10592.50
# Oeste      14280.50
# Name: Ventas, dtype: float64

# %%
#6. ORdenar por ventas en orden descendente
df_descendente=df_ventas.sort_values(by='Ventas', ascending=False)
df_descendente
# Out:
#                                                 Fecha   Region      Producto  \
# 18                                                NaN      NaN           NaN
# 16                                2024-02-16 00:00:00    Oeste      Sistemas
# 13                                2024-02-05 00:00:00  Central      Sistemas
# 17                                2024-02-17 00:00:00    Oeste      Sistemas
# 12                                2024-02-04 00:00:00  Central      Sistemas
# 14                                2024-02-10 00:00:00     Este      Sistemas
# 15                                2024-02-11 00:00:00     Este      Sistemas
# 7                                 2024-02-03 00:00:00  Central  Dispositivos
# 6                                 2024-02-02 00:00:00  Central  Dispositivos
# 10                                2024-02-14 00:00:00    Oeste  Dispositivos
# 8                                 2024-02-08 00:00:00     Este  Dispositivos
# ...

# %%
#7. Filtrar filas con ventas mayores a 10000 y ordenar de mayor a menor
df_ventas_mayores=df_ventas[df_ventas['Ventas']>10000].sort_values(by='Ventas', ascending=True)
df_ventas_mayores
# Out:
#                   Fecha   Region      Producto Vendedor    Ventas Unnamed: 5
# 8   2024-02-08 00:00:00     Este  Dispositivos      Ana   10348.0        NaN
# 10  2024-02-14 00:00:00    Oeste  Dispositivos    Kevin   10711.0        NaN
# 6   2024-02-02 00:00:00  Central  Dispositivos    David   11420.0        NaN
# 7   2024-02-03 00:00:00  Central  Dispositivos    Karen   12948.0        NaN
# 15  2024-02-11 00:00:00     Este      Sistemas    Lucas   13374.0        NaN
# 14  2024-02-10 00:00:00     Este      Sistemas      Ana   13531.0        NaN
# 12  2024-02-04 00:00:00  Central      Sistemas    David   20098.0        NaN
# 17  2024-02-17 00:00:00    Oeste      Sistemas     Sara   23151.0        NaN
# 13  2024-02-05 00:00:00  Central      Sistemas    Karen   30633.0        NaN
# 16  2024-02-16 00:00:00    Oeste      Sistemas    Kevin   32855.0        NaN
# 18                  NaN      NaN           NaN      NaN  239533.0        NaN

# %%
#8. Ordenar el dataframe en orden descendente
df_descendente=df_ventas.sort_values(by='Ventas', ascending=False)
df_descendente
# Out:
#                                                 Fecha   Region      Producto  \
# 18                                                NaN      NaN           NaN
# 16                                2024-02-16 00:00:00    Oeste      Sistemas
# 13                                2024-02-05 00:00:00  Central      Sistemas
# 17                                2024-02-17 00:00:00    Oeste      Sistemas
# 12                                2024-02-04 00:00:00  Central      Sistemas
# 14                                2024-02-10 00:00:00     Este      Sistemas
# 15                                2024-02-11 00:00:00     Este      Sistemas
# 7                                 2024-02-03 00:00:00  Central  Dispositivos
# 6                                 2024-02-02 00:00:00  Central  Dispositivos
# 10                                2024-02-14 00:00:00    Oeste  Dispositivos
# 8                                 2024-02-08 00:00:00     Este  Dispositivos
# ...

# %%
#6. Eliminar columna Vendedor
df_sin_vendedor=df_ventas.drop(columns=['Vendedor'])
df_sin_vendedor
# Out:
#                                                 Fecha   Region      Producto  \
# 0                                 2024-01-31 00:00:00  Central    Accesorios
# 1                                 2024-02-01 00:00:00  Central    Accesorios
# 2                                 2024-02-06 00:00:00     Este    Accesorios
# 3                                 2024-02-07 00:00:00     Este    Accesorios
# 4                                 2024-02-12 00:00:00    Oeste    Accesorios
# 5                                 2024-02-13 00:00:00    Oeste    Accesorios
# 6                                 2024-02-02 00:00:00  Central  Dispositivos
# 7                                 2024-02-03 00:00:00  Central  Dispositivos
# 8                                 2024-02-08 00:00:00     Este  Dispositivos
# 9                                 2024-02-09 00:00:00     Este  Dispositivos
# 10                                2024-02-14 00:00:00    Oeste  Dispositivos
# ...

# %% [markdown]
# # Agregación y agrupación de datos
#
# * Calcular el total de ventas por región
# * Calcular el total de ventas por producto

# %%
#1. Calcular el total de ventas por region
ventas_region=df_ventas.groupby('Region')['Ventas'].sum()
ventas_region
# Out:
# Region
# Central    90295.0
# Este       63555.0
# Oeste      85683.0
# Name: Ventas, dtype: float64

# %%
#2. CAlcular el total de ventas por Producto
ventas_region=df_ventas.groupby('Producto')['Ventas'].sum()
ventas_region
# Out:
# Producto
# Accesorios       42372.0
# Dispositivos     63519.0
# Sistemas        133642.0
# Name: Ventas, dtype: float64
